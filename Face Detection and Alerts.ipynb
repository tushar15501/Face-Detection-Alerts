# %% [markdown]
# # Prediction with created Face Recognizer Model

# %%
import cv2
import numpy as np
subjects = ["", "Tushar", "Vimal"]
def draw_rectangle(img, rect):
    if rect == []:
        return img
    else:
        (x, y, w, h) = rect
        return cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    
def draw_text(img, text):
    if img is not None:
        cv2.putText(img, text, (200, 100), cv2.FONT_HERSHEY_COMPLEX, 1.5, (0, 0, 255), 5)

def face_extractor(img ):
    
    faces = face_classifier.detectMultiScale(img, 1.4, 2)
    if faces == ():
        return img, []
    
    else:
        for (x,y,w,h) in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
            detected_face = img[y:y+h, x:x+w]
            detected_face = cv2.resize(detected_face, (200, 200))
            return detected_face, faces[0]
        
cap = cv2.VideoCapture(0)
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_recognizer = cv2.face_LBPHFaceRecognizer.create() 
face_recognizer.read("face_recognizer.h5")
while True:
   
        ret, frame = cap.read()
        face, rect = face_extractor(frame)
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)      
        label = face_recognizer.predict(face)
        label_text = subjects[label[0]]
        print(label)
        x = draw_rectangle(frame, rect )
        #draw_text(frame, label_text, rect[0][0], rect[0][1]-5)
        draw_text(x, label_text)
        cv2.imshow("Hii", frame)
        if cv2.waitKey(1) == 13:
            break
        
   
        
cv2.destroyAllWindows()
cap.release()
# Out:
# <ipython-input-1-b514b362073f>:19: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# <ipython-input-1-b514b362073f>:5: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if rect == []:
# (1, 51.791058648635264)
# (1, 55.62832323335889)
# (1, 54.9957596215048)
# (1, 51.706434637760154)
# (1, 55.48490403877268)
# (1, 54.66349130853701)
# (1, 55.48711040914088)
# (1, 55.4060868144192)
# (1, 55.37872098807233)
# (1, 57.40630111798054)
# (1, 57.15856795524651)
# (1, 57.056273526434744)
# (1, 55.65787092876377)
# (1, 55.45899928238885)
# (1, 55.16119021686258)
# (1, 55.98303978914516)
# (1, 56.438533499704434)
# (1, 50.751219793023395)
# (1, 51.261683404218694)
# (1, 49.21461667120942)
# (2, 59.939288896840715)
# (1, 62.79108669625751)
# (1, 62.357180373335886)
# (1, 71.75683377546096)
# (2, 61.33670219181305)
# (2, 60.31547188630022)
# (2, 59.93359573693908)
# (2, 56.84462745821533)
# (2, 56.34949323403926)
# (2, 57.24149423014069)
# (2, 56.702485778369415)
# (2, 57.30401908553585)
# (2, 60.118482480263445)
# (2, 61.08802731988286)
# (2, 62.23604915969907)
# (2, 61.08550707268706)
# (2, 61.22112968436876)
# (2, 63.29869409167179)
# (2, 64.34041594114888)
# (2, 64.51525087464803)
# (1, 64.62310837777551)
# (1, 64.22484620209065)
# (1, 59.661511129112334)
# (1, 57.591498980023594)
# (1, 54.04821912173353)
# (1, 55.21462201148811)
# (1, 54.34628577840268)
# (1, 54.15190140104652)
# (1, 52.00422616607383)
# (1, 42.16556524583694)
# (1, 48.019712835330935)
# (1, 53.99665776484747)
# (2, 55.24162802151017)
# (2, 59.48340088401706)
# (1, 59.300909565637994)
# (1, 41.57101058897831)
# (1, 41.32845558964096)
# (1, 43.13340735143754)
# (1, 43.69644745588116)
# (1, 41.65069324078104)
# (1, 44.969046681111884)
# (1, 41.580411994606074)
# (1, 41.74343418065184)
# (1, 43.63420613840779)
# (1, 43.71995780987624)
# (1, 42.7284475920111)
# (1, 45.82456222619331)
# (1, 47.936141642458594)
# (1, 49.081999801508516)
# (1, 58.785997216222384)
# (1, 56.549312034857294)
# (1, 51.56865150588489)
# (1, 47.5455791295576)

# %% [markdown]
# # Function for Email

# %%
import smtplib
import os
import getpass
import imghdr         
from email.message import EmailMessage         #for setting and querying header fields, for accessing message bodies, for creating or modifying structured messages

def send_email():
    message = EmailMessage()
    
    Sender_Mail = os.environ.get('MY_EMAIL')
    Sender_Password = os.environ.get("SenderPassword")
    Receiver_mail = os.environ.get("Recvmail")
  
    
    # print("Sending mail....")
    
    message['subject'] = "Intruder Detected..."
    message['from'] = Sender_Mail
    message['to'] = Receiver_mail
    message.set_content("Welcome to Face recognition app" )
    
   # converting image into byte format, as we need byte data to dend over network
    with open("./image/Crop.jpg" , "rb") as attach_file:
        image_name = attach_file.name
        image_type = imghdr.what(attach_file.name)
        image_data = attach_file.read()
    
    #specifying the content of mail to be sent.
    message.add_attachment(image_data , maintype = "image", subtype = image_type , filename = "FaceLock.png")
    
    #to connect with gmail server
    with smtplib.SMTP_SSL("smtp.gmail.com",465) as smtp:
        smtp.login(Sender_Mail,Sender_Password)
        smtp.send_message(message)
        
    # print("Mail Sent sucessfully")
    
#send_email()

# %% [markdown]
# # Function for Whatsapp

# %%
import pywhatkit 
import os
from datetime import datetime                        #datetime module to get current time

def do_whatsapp():
    #now = datetime.now()           # Get current time
    #hr = int(now.strftime("%H"))   # Current Hour
    #min = int( now.strftime("%M"))  # Current mint
    
    ContactNo =os.environ.get('contactNo.')
    pywhatkit.sendwhatmsg_instantly(ContactNo , "Intruder trying to enter into your space. Please Check...")
    
# do_whatsapp()

# %% [markdown]
# # Function for Face detection

# %%
import time
def condition():
    if Tushar == 100:
        tf = cv2.imread("images.jpg")
        cv2.putText(tf, "Access", (45, 50) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(tf, "Granted", (45, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("permission" , tf)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        print("Verified User...")
        
    elif Vimal == 25:
        tm = cv2.imread("images.jpg")
        cv2.putText(tm, "Access", (45, 50) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(tm, "Granted", (45, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("permission" , tm)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        print("Verified User...")
      
    elif Anon == 150:
        lock = cv2.imread("lock.jpg")
        cv2.putText(lock, "Access", (45, 50) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(lock, "Denied", (45, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("lock" , lock)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        cv2.imshow("lock" , image)
        cv2.waitKey(1000)
        cv2.destroyAllWindows()
        face_anon = face_classifier.detectMultiScale(image, 1.4, 6)
        for x,y,w,h in face_anon:
            cimg1 = image[y:y+h, x:x+w,  : ]
            cv2.imwrite("./image/Crop.jpg",cimg1)  
        print("Sending Mail...")
        send_email()
        print("Mail sent sucessfully")
        print("Sending Whatsapp message...")
        do_whatsapp()
        print("WhatsApp Done sucessfully")

# %% [markdown]
# # Face Detection and alerts

# %%
import cv2
import numpy as np
import os
import time

Face_recognizer  = cv2.face_LBPHFaceRecognizer.create() 
Face_recognizer.read("face_recognizer.h5")
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img ):
    
    faces = face_classifier.detectMultiScale(img, 1.4,3)
    if faces is ():
        return img, []
    else:
        for (x,y,w,h) in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
            detected_face = img[y:y+h, x:x+w]
            detected_face = cv2.resize(detected_face, (200, 200))
            return img, detected_face

# Open Webcam
cap = cv2.VideoCapture(0)
Tushar = 0
Anon = 0
Vimal = 0

while True:

    ret, frame = cap.read()
    image, detected_face = face_detector(frame)

    try:
        face = cv2.cvtColor(detected_face, cv2.COLOR_BGR2GRAY)        
        model_output = Face_recognizer.predict(face)
        
        if model_output[1] < 500:
            confidence = int( 100 * (1 - (model_output[1])/400) )
            display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if model_output[0] == 2 and confidence >= 80:
            cv2.putText(image, "Hello Vimal", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 2)
            cv2.imshow('Face Recognition', image )
            Vimal += 1
            
        elif model_output[0]== 1 and confidence >=80:
            cv2.putText(image, "Hello Tushar", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            Tushar+= 1
            
        else :
            cv2.putText(image, "Anonymous face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,255), 2)
            cv2.imshow('Face Recognition', image )
            Anon += 1
            
                    
        if Tushar == 100:
            print("Access Granted") 
            break
            
        elif Vimal == 25:
            print("Access Granted")
            break
            
        elif Anon == 150:
            print("Anonymous person found")
            break
                    
    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(10) == 13: 
        break
        

cv2.destroyAllWindows()
cap.release()
condition()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-9388ec39116d>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Anonymous person found
# Sending Mail...
# Mail sent sucessfully
# Sending Whatsapp message...
# WhatsApp Done sucessfully

# %%
print(int('014'))
# Out:
# 14

# %%
os.environ['MY_EMAIL'] = 'joshitushar210@gmail.com'

# %%
os.environ['SenderPassword'] = 'ckcoakeohuznhdlr'

# %%
os.environ['Recvmail'] = 'tushar.21910413@viit.ac.in'

# %%
os.environ['contactNo.'] = '+919834452882'

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\hp\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'LAPTOP-7HHHL000',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_3652': '1',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\hp',
#         'LOCALAPPDATA': 'C:\\Users\\hp\\AppData\\Local',
#         'LOGONSERVER': '\\\\LAPTOP-7HHHL000',
#         'NUMBER_OF_PROCESSORS': '8',
#         'ONEDRIVE': 'C:\\Users\\hp\\OneDrive',
#         'ONLINESERVICES': 'Online Services',
#         'OS': 'Windows_NT',
#         'PATH': 'C:\\Users\\hp\\anaconda3\\Lib\\site-packages\\cv2\\../../x64/vc14/bin;C:\\Users\\hp\\anaconda3;C:\\Users\\hp\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\hp\\anaconda3\\Library\\usr\\bin;C:\\Users\\hp\\anaconda3\\Library\\bin;C:\\Users\\hp\\anaconda3\\Scripts;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Git\\cmd;C:\\Program Files\\Matlab\\R2020a\\runtime\\win64;C:\\Program Files\\Matlab\\R2020a\\bin;C:\\Program Files\\Matlab\\R2020a\\polyspace\\bin;C:\\Program Files (x86)\\Microsoft\\Edge\\Application;C:\\Program Files (x86)\\Google\\Chrome\\Application;C:\\Program Files\\Quick Heal\\Quick Heal AntiVirus Pro;C:\\Program Files (x86)\\VideoLAN\\VLC;C:\\Program Files (x86)\\Windows Media Player;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Amazon\\AWSCLIV2\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Users\\hp\\anaconda3;C:\\Users\\hp\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\hp\\anaconda3\\Library\\usr\\bin;C:\\Users\\hp\\anaconda3\\Library\\bin;C:\\Users\\hp\\anaconda3\\Scripts;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Users\\hp\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Program Files\\Oracle\\VirtualBox;C:\\Users\\hp\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Program Files\\Kubernetes\\Minikube;C:\\Program Files\\Perforce;C:\\Program Files (x86)\\Microsoft SDKs\\Azure\\CLI2\\python.exe;C:\\Users\\hp\\eclipse\\java-2020-12\\eclipse\\eclipse.exe;C:\\Users\\hp\\AppData\\Roaming\\Microsoft\\Windows\\Start Menu\\Programs\\Anaconda3 (64-bit);C:\\Program Files\\nodejs;C:\\flutter_windows_2.2.1-stable\\flutter\\bin;C:\\Program Files (x86)\\windows-amd64;C:\\xampp;C:\\Program Files\\dart-sdk\\bin;C:\\Program Files\\JetBrains\\PyCharm Community Edition 2022.2.3\\bin;D:\\flutter\\bin;C:\\Users\\hp\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Program Files\\Android\\Android Studio_new;D:\\flutter\\bin;C:\\Users\\hp\\AppData\\Local\\Pub\\Cache\\bin;C:\\Program Files\\Android\\Android Studio',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PLATFORMCODE': 'KV',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 158 Stepping 10, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '9e0a',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYCHARM COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\PyCharm Community Edition 2022.2.3\\bin;',
#         'REGIONCODE': 'APJ',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\WINDOWS',
#         'TEMP': 'C:\\Users\\hp\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\hp\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'LAPTOP-7HHHL000',
#         'USERDOMAIN_ROAMINGPROFILE': 'LAPTOP-7HHHL000',
#         'USERNAME': 'hp',
#         'USERPROFILE': 'C:\\Users\\hp',
#         'VBOX_MSI_INSTALL_PATH': 'C:\\Program Files\\Oracle\\VirtualBox\\',
#         'WINDIR': 'C:\\WINDOWS',
#         'CONDA_PREFIX': 'C:\\Users\\hp\\anaconda3',
#         'JPY_INTERRUPT_EVENT': '3316',
#         'IPY_INTERRUPT_EVENT': '3316',
#         'JPY_PARENT_PID': '3264',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#         'MY_EMAIL': 'joshitushar210@gmail.com',
#         'SENDERPASSWORD': 'ckcoakeohuznhdlr',
#         'RECVMAIL': 'tushar.21910413@viit.ac.in',
#         'CONTACTNO.': '+919834452882'}
