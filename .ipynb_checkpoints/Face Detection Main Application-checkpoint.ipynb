# %%
import cv2
import numpy as np
subjects = ["", "User1", "User2"]
def draw_rectangle(img, rect):
    if rect == []:
        return img
    else:
        (x, y, w, h) = rect
        return cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    
def draw_text(img, text):
    if img is not None:
        cv2.putText(img, text, (200, 100), cv2.FONT_HERSHEY_COMPLEX, 1.5, (0, 0, 255), 5)

def face_extractor(img ):
    
    faces = face_classifier.detectMultiScale(img, 1.4, 2)
    if faces == ():
        return img, []
    
    else:
        for (x,y,w,h) in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
            detected_face = img[y:y+h, x:x+w]
            detected_face = cv2.resize(detected_face, (200, 200))
            return detected_face, faces[0]
        
cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')
face_recognizer = cv2.face_LBPHFaceRecognizer.create() 
face_recognizer.read("face_recognizer.h5")
while True:
   
        ret, frame = cap.read()
        face, rect = face_extractor(frame)
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)      
        label = face_recognizer.predict(face)
        label_text = subjects[label[0]]
        print(label)
        x = draw_rectangle(frame, rect )
        draw_text(x, label_text)
        cv2.imshow("hii", frame)
        if cv2.waitKey(1) == 13:
            break
        
   
        
cv2.destroyAllWindows()
cap.release()
# Out:
# <ipython-input-1-b6b1fa8852db>:19: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# <ipython-input-1-b6b1fa8852db>:5: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if rect == []:
# (1, 40.726358797778865)
# (1, 39.731822320509984)
# (1, 39.76111424166008)
# (1, 38.455912485710385)
# (1, 41.11062852983369)
# (1, 38.88380962719758)
# (1, 38.91351818060031)
# (1, 38.353492589090166)
# (1, 39.91829792333504)
# (1, 37.951619600832466)
# (1, 38.66981754314172)
# (1, 40.4099230722218)
# (1, 40.56856794597153)
# (1, 40.37152078359936)
# (1, 38.67560563582454)
# (1, 38.49086331655103)
# (1, 40.168552759779196)
# (1, 40.68189404142724)
# (1, 37.82342602038237)
# (1, 40.07675819300417)
# (1, 39.84736513075404)
# (1, 40.69506798311544)
# (1, 42.60720599289053)
# (1, 40.0459358405916)
# (1, 39.540874374930816)
# (1, 39.45239852830971)
# (1, 41.08084753462325)
# (1, 42.2685420183231)
# (1, 39.16853801221171)
# (1, 41.839678980850245)
# (1, 39.131832237029315)
# (1, 42.883540276256895)
# (1, 41.10033498569259)
# (1, 42.340849005546275)
# (1, 38.99283748449425)
# (1, 46.05869319296545)
# (1, 43.15951816194708)
# (1, 43.41332983736251)
# (1, 42.347479903484654)
# (1, 41.41499015647515)
# (1, 43.50317896299583)
# (1, 42.65309851525131)
# (1, 41.886122536098185)
# (1, 42.696901971364824)
# (1, 42.71804206905466)
# (1, 43.84443809866227)
# (1, 42.48895292124145)
# (1, 42.4553628429252)
# (1, 42.78796990315021)
# (1, 42.12321193108673)
# (1, 42.90153354988056)
# (1, 41.643526050153994)
# (1, 43.58564092209136)
# (1, 43.246749359805406)
# (1, 45.32112086343891)
# (1, 44.00378213089294)
# (1, 42.67226779370108)
# (1, 41.82332916800023)
# (1, 41.91144592927421)
# (1, 43.67784927999491)
# (1, 41.128203999072475)
# (1, 42.00862598426538)
# (1, 43.93599647495105)
# (1, 42.261439237626455)
# (1, 42.87475859241335)
# (1, 41.64897924249683)
# (1, 40.45438815732533)
# (1, 41.55374771366876)
# (1, 42.021183623988065)
# (1, 42.57814354469159)
# (1, 42.24603543084558)
# (1, 40.18299870818394)
# (1, 42.14377215402742)
# (1, 42.12182844203207)
# (1, 43.78804939729188)
# (1, 41.914061940462915)
# (1, 43.20056745930363)
# (1, 43.58812518191098)
# (1, 43.043117519460004)
# (1, 42.346564525831475)
# (1, 44.43770573685074)
# (1, 43.81042399537112)
# (1, 43.231747041210895)
# (1, 43.07926406710215)
# (1, 44.57500970832214)
# (1, 43.128766919458286)
# (1, 44.47531382261475)
# (1, 43.81590933682127)
# (1, 43.27573772437116)
# (1, 44.07804650417051)
# (1, 42.652105166431745)

# %% [markdown]
# # Function for Email

# %%
import smtplib
import os
import getpass
import imghdr  
import time
import time_str
from email.message import EmailMessage         #for setting and querying header fields, for accessing message bodies, for creating or modifying structured messages

def send_email():
    message = EmailMessage()
    
    Sender_Mail = os.environ.get('MY_EMAIL')
    Sender_Password = os.environ.get("SenderPassword")
    Receiver_mail = os.environ.get("Recvmail")
      
    
    message['subject'] = "Intrder Detected.."
    message['from'] = Sender_Mail
    message['to'] = Receiver_mail
    message.set_content("Welcome to Face recognition app" )
    
   
    with open("./image/Crop.jpg" , "rb") as attach_file:
        image_name = attach_file.name
        image_type = imghdr.what(attach_file.name)
        image_data = attach_file.read()

        # attach the image to the email message
    message.add_attachment(image_data, maintype="image", subtype=image_type, filename=image_name)

        
    #to connect with gmail server
    with smtplib.SMTP_SSL("smtp.gmail.com",465) as smtp:
        smtp.login(Sender_Mail,Sender_Password)
        smtp.send_message(message)
            
#send_email()

# %%
import smtplib
import os
import getpass
import imghdr
from email.message import EmailMessage
import time

def send_email_new():
    message = EmailMessage()
    
    Sender_Mail = os.environ.get('MY_EMAIL')
    Sender_Password = os.environ.get("SenderPassword")
    Receiver_mail = os.environ.get("Recvmail")
  
    # set email message properties
    message['subject'] = "Intruder Detected..."
    message['from'] = Sender_Mail
    message['to'] = Receiver_mail
    message.set_content("Welcome to Face recognition app" )
    
    
    # read image file and attach to email message
    with open("./image/Crop.jpg" , "rb") as attach_file:
        image_name = attach_file.name
        image_type = imghdr.what(attach_file.name)
        image_data = attach_file.read()
    
    #specifying the content of mail to be sent.
    message.add_attachment(image_data , maintype = "image", subtype = image_type , filename = "FaceLock.png")
    
    
    # connect with gmail server and send email
    with smtplib.SMTP_SSL("smtp.gmail.com",465) as smtp:
        smtp.login(Sender_Mail,Sender_Password)
        smtp.send_message(message)
    
    #print("Email sent successfully.")

# %% [markdown]
# # Function for Whatsapp

# %%
import pywhatkit 
import os
from datetime import datetime                        #datetime module to get current time

def do_whatsapp():
    #now = datetime.now()           # Get current time
    #hr = int(now.strftime("%H"))   # Current Hour
    #min = int( now.strftime("%M"))  # Current mint
    
    ContactNo =os.environ.get('contactNo.')

    pywhatkit.sendwhatmsg_instantly(ContactNo,"Intrduer trying to enter into your working area. Please Check...")

#do_whatsapp()

# %% [markdown]
# # Function for Face detection Application

# %%
import time
import time_str
def condition():
    if User1 == 100:
        tf = cv2.imread("images.jpg")
        cv2.putText(tf, "Access", (45, 50) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(tf, "Granted", (45, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("permission" , tf)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        print("ACCESS GRANTED....")
         
    elif User2 == 25:
        tm = cv2.imread("images.jpg")
        cv2.putText(tm, "Access Granted", (50, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("Permission", tm)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        print("ACCESS GRANTED...")
            
    elif Anon == 150:
        lock = cv2.imread("lock.jpg")
        cv2.putText(lock, "Access", (45, 50) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(lock, "Denied", (45, 100) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow("lock" , lock)
        cv2.waitKey(2000)
        cv2.destroyAllWindows()
        cv2.imshow("lock" , image)
        cv2.waitKey(1000)
        cv2.destroyAllWindows()
        images = cv2.imread("./image/Crop.jpg")
        face_anon = face_classifier.detectMultiScale(images, 1.4, 6)
        for x,y,w,h in face_anon:
            cimg1 = image[y:y+h, x:x+w,  : ]
            cv2.imwrite("./image/Crop.jpg",cimg1)
        print("Sending Mail...")
        send_email_new()
        print("Mail sent sucessfully")
        print("Sending Whatsapp message...")
        do_whatsapp()
        print("WhatsApp Done sucessfully")

# %%
import cv2
import numpy as np
import os
import time

Face_recognizer  = cv2.face_LBPHFaceRecognizer.create() 
Face_recognizer.read("face_recognizer.h5")
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

def face_detector(img ):
    
    faces = face_classifier.detectMultiScale(img, 1.4,3)
    if faces is ():
        return img, []
    else:
        for (x,y,w,h) in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
            detected_face = img[y:y+h, x:x+w]
            detected_face = cv2.resize(detected_face, (200, 200))
            return img, detected_face

# Open Webcam
cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
User1 = 0
Anon = 0
User2 = 0

while True:

    ret, frame = cap.read()
    image, detected_face = face_detector(frame)

    try:
        face = cv2.cvtColor(detected_face, cv2.COLOR_BGR2GRAY)        
        model_output = Face_recognizer.predict(face)
        
        if model_output[1] < 500:
            confidence = int( 100 * (1 - (model_output[1])/400) )
            display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if model_output[0] == 2 and confidence >70:
            cv2.putText(image, "Verified User", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 2)
            cv2.imshow('Face Recognition', image )
            User2 += 1
            
        elif model_output[0]== 1 and confidence >90:
            cv2.putText(image, "Verified User", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            User1 += 1
            
        else:
            cv2.putText(image, "Anonymous face found", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,255), 2)
            cv2.imshow('Face Recognition', image )
            Anon += 1
            
                    
        if User1 == 100:
            print("Success") 
            break
            
        elif User2 == 25:
            print("Success")
            break
            
        elif Anon == 150:
            print("Anonymous person found")            
            break
                    
    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(1) == 13: 
        break
        

cv2.destroyAllWindows()
cap.release()
condition()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-6-ed84ae3fcf12>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
os.environ['MY_EMAIL'] = 'joshitushar210@gmail.com'

# %%
os.environ['SenderPassword'] = 'ckcoakeohuznhdlr'

# %%
os.environ['Recvmail'] = 'tushar.21910413@viit.ac.in'

# %%
os.environ['contactNo.'] = '+919834452882'

# %%
os.environ['Recvmail'] = 'aditya.21910610@viit.ac.in'
